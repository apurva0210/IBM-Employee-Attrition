# %%
import pandas as pd                         # for data reading
import numpy as np
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize

# %%
print("Pandas version: ",pd.__version__)
print("Seaborn version: ",sns.__version__)
print("Matplotlib version: ",mat.__version__)
# Out:
# Pandas version:  1.4.4
# Seaborn version:  0.11.2
# Matplotlib version:  3.5.2

# %% [markdown]
# ## Reading The File

# %%
df=pd.read_csv("DS1_C6_S2_EmployeeAttrition_Data_Concept.csv")
df
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     41.0       Yes      Travel_Rarely                   Sales
# 1     49.0        No  Travel_Frequently  Research & Development
# 2     37.0       Yes      Travel_Rarely  Research & Development
# 3     33.0        No  Travel_Frequently  Research & Development
# 4     27.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 0                    1  Life Sciences               1
# 1                    8  Life Sciences               2
# ...

# %% [markdown]
# #  Understanding Data

# %% [markdown]
# ## Reading the top 5 rows

# %%
df.head()
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  41.0       Yes      Travel_Rarely                   Sales
# 1  49.0        No  Travel_Frequently  Research & Development
# 2  37.0       Yes      Travel_Rarely  Research & Development
# 3  33.0        No  Travel_Frequently  Research & Development
# 4  27.0        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0                 1  Life Sciences               1                        2
# 1                 8  Life Sciences               2                        3
# 2                 2          Other               4                        4
# 3                 3  Life Sciences               5                        4
# 4                 2        Medical               7                        1
#
#    Gender  HourlyRate  ...  OverTime PerformanceRating  \
# 0  Female          94  ...       Yes                 3
# ...

# %% [markdown]
# ## Reading the bottom 5 rows

# %%
df.tail()
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 1465                23        Medical            2061
# 1466                 6        Medical            2062
# 1467                 4  Life Sciences            2064
# 1468                 2        Medical            2065
# 1469                 8        Medical            2068
#
#       EnvironmentSatisfaction Gender  HourlyRate  ...  OverTime  \
# 1465                        3   Male          41  ...        No
# 1466                        4   Male          42  ...        No
# ...

# %% [markdown]
# ## Number of rows and columns

# %%
print(df.shape)
# Out:
# (1470, 27)

# %% [markdown]
# ## Display the names of all the columns

# %%
print(df.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## Displaying dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1446 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1440 non-null   object
#  3   Department                1466 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   EducationField            1458 non-null   object
#  6   EmployeeNumber            1470 non-null   int64
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1425 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobRole                   1460 non-null   object
#  12  JobSatisfaction           1470 non-null   int64
# ...

# %% [markdown]
# ## Describe the dataset information

# %%
df.describe()
# Out:
#                Age  DistanceFromHome  EmployeeNumber  EnvironmentSatisfaction  \
# count  1446.000000       1470.000000     1470.000000              1470.000000
# mean     36.930152          9.192517     1024.865306                 2.721769
# std       9.162204          8.106864      602.024335                 1.093082
# min      18.000000          1.000000        1.000000                 1.000000
# 25%      30.000000          2.000000      491.250000                 2.000000
# 50%      36.000000          7.000000     1020.500000                 3.000000
# 75%      43.000000         14.000000     1555.750000                 4.000000
# max      60.000000         29.000000     2068.000000                 4.000000
#
#         HourlyRate  JobInvolvement  JobSatisfaction  MonthlyIncome  \
# count  1470.000000     1470.000000      1470.000000    1470.000000
# mean     65.891156        2.729932         2.728571    6502.931293
# ...

# %% [markdown]
# ## Checking if there are any null values in columns

# %%
df.isnull().sum()
# Out:
# Age                         24
# Attrition                    0
# BusinessTravel              30
# Department                   4
# DistanceFromHome             0
# EducationField              12
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                      45
# HourlyRate                   0
# JobInvolvement               0
# JobRole                     10
# JobSatisfaction              0
# MaritalStatus               56
# MonthlyIncome                0
# NumCompaniesWorked           0
# Over18                      54
# OverTime                     0
# PerformanceRating            0
# RelationshipSatisfaction     0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsInCurrentRole           0
# YearsSinceLastPromotion      0
# YearsWithCurrManager         0
# dtype: int64

# %% [markdown]
# ## Seperating Categorical & Numerical Variables

# %%
def seprate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:                # looping on the number of columns
        if df[column].nunique() < 30:       # nunique:  returns unique values in the column,
                                                    #here 30 is the hyperparamter and can be changed
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(df)         # Calling the function

# # Tabulate is a package used to print the list, dict or any data sets in a proper format; in table format
from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  -----------------
# Attrition                 Age
# BusinessTravel            EmployeeNumber
# Department                HourlyRate
# DistanceFromHome          MonthlyIncome
# EducationField            TotalWorkingYears
# EnvironmentSatisfaction   YearsAtCompany
# Gender
# JobInvolvement
# JobRole
# JobSatisfaction
# MaritalStatus
# NumCompaniesWorked
# Over18
# OverTime
# PerformanceRating
# RelationshipSatisfaction
# TrainingTimesLastYear
# WorkLifeBalance
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %% [markdown]
# # $$\;\;\;\; Univariate \ Analysis \ of \ Categorical \ Variables$$

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") # unique: returns the unique values in the col
    print(f"Mode of {col} is {df[col].mode()[0]}")  # mode: returns the mode of the column
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}") # isnull().sum() counts the number of null in dataframe

# %% [markdown]
# ## 1. Analysis of Attrition : If the account is closed, then Yes else No

# %%
info_of_cat("Attrition")
# Out:
# Unique values in Attrition are: ['Yes' 'No']
# Mode of Attrition is No
# Number of missing values in Attrition is 0

# %% [markdown]
# ###### Attrition is a nominal datatype.

# %% [markdown]
# ## Visual Presentation of Attrition  Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "Attrition" column
data = df["Attrition"].value_counts()

# Get the unique categories (labels) in the "Attrition" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set1', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='Attrition', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Attrition Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.03]*len(labels), shadow=True, startangle=30)
plt.title("Attrition Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation:  The dataset indicates that 16% of the employees left the company while 84% of the employees are still with the company.

# %% [markdown]
# ## 2. Analysis of Business Travel : If the type of business travel is Travel_Rarel , Travel_Frequently & Non-Travel

# %%
info_of_cat("BusinessTravel")
# Out:
# Unique values in BusinessTravel are: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel' nan]
# Mode of BusinessTravel is Travel_Rarely
# Number of missing values in BusinessTravel is 30

# %% [markdown]
# ###### BusinessTravel is a nominal datatype.

# %% [markdown]
# ###    Optional::Way to fill: Mode of the Businesstravel Column
#
# Note: Mode is not the perfect way to fill the missing value in this case. One might need to handle such a situation with caution. This is for demonstration purposes only.

# %%
BusinessTravel_mode = df.BusinessTravel.mode()[0]
print(BusinessTravel_mode)
df["BusinessTravel"].fillna(BusinessTravel_mode, inplace = True)
# Out:
# Travel_Rarely

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "BusinessTravel" column
data = df["BusinessTravel"].value_counts()

# Get the unique categories (labels) in the "BusinessTravel" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set3', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='BusinessTravel', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Business Travel Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.02]*len(labels), shadow=True, startangle=90)
plt.title("Business Travel Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: The Dataset indicates that 72% of employees use Business Travels Rarely, 18% of employees use Business Travels Frequently & 10% of Employees don't like Business Travel.

# %% [markdown]
# ## 3.Analysis of Department field: The department that the employee works in

# %%
info_of_cat("Department")
# Out:
# Unique values in Department are: ['Sales' 'Research & Development' 'Human Resources' nan]
# Mode of Department is Research & Development
# Number of missing values in Department is 4

# %% [markdown]
# ###### Department is a nominal datatype.

# %%
Dep_mode = df.Department.mode()[0]
print(Dep_mode)
df["Department"].fillna(Dep_mode, inplace = True)
# Out:
# Research & Development

# %% [markdown]
# ## Visual presentation of Department Attribute

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Calculate the value counts of the "Department" column
data = df["Department"].value_counts()

# Get the unique categories (labels) in the "Department" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set2', n_colors=len(labels))

# Plot a count plot on the first subplot
sns.countplot(x='Department', data=df, order=labels, palette=colors, ax=axes[0])
axes[0].set_title("Department Count")

# Plot a donut pie chart on the second subplot
wedges, texts, autotexts = axes[1].pie(data, labels=labels, colors=colors, autopct="%0.2f%%", startangle=30, wedgeprops=dict(width=0.4))
center_circle = plt.Circle((0, 0), 0.3, color='white')
axes[1].add_artist(center_circle)
axes[1].set_title("Department Distribution")

# Set aspect ratio to be equal to ensure a circular shape in the pie chart
axes[1].axis('equal')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.4)

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: 65.3% of employees work in Research & Development and only 4.29% work in Human resources.

# %% [markdown]
# ## 4.Analysis of Distance from Home: Distance from the home of an employee in km

# %%
info_of_cat("DistanceFromHome")
# Out:
# Unique values in DistanceFromHome are: [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
# Mode of DistanceFromHome is 2
# Number of missing values in DistanceFromHome is 0

# %% [markdown]
# ###### DistanceFromHome is an ordinal datatype (Categorical) as it has a hierarchy in it.

# %% [markdown]
# ## ***Interpretation: The distance from the home of some employees is too long. This could be a result of human error in data.

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["DistanceFromHome"])
ax.set_title("Distance From Home Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
    fig.set_figheight(10)                                                             # annotate: used to annotate over objects, here objects are the bars
    fig.set_figwidth(30)
plt.show()

# %% [markdown]
# ## ***Interpretation: Very few people have less than a distance from home. However, there are some cases where the distance from home is greater than 29, which is abnormal. Hence, data clearing might be required.

# %% [markdown]
# ## Outliers Analysis & Treatment

# %%
#IQR method for outfilers treatment
Q1 = df['DistanceFromHome'].quantile(0.25)
Q3 = df['DistanceFromHome'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 12.0

# %% [markdown]
# The employees who have a greater than 12 km Distance from home are being replaced with the mean of the distance.

# %%
mean = int(df.DistanceFromHome.mean())
# accessing the data higher than 12
x = df[df["DistanceFromHome"] > 12].index
for index in x:
    df.loc[index, "DistanceFromHome"] = mean

# %%
info_of_cat("DistanceFromHome")
# Out:
# Unique values in DistanceFromHome are: [ 1  8  2  3  9  5 11  7  6 10  4 12]
# Mode of DistanceFromHome is 9
# Number of missing values in DistanceFromHome is 0

# %% [markdown]
# ## Visual Presentation of Distance from Home Attribute

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["DistanceFromHome"])
ax.set_title("Distance From Home Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
                                                                    # annotate: used to annotate over objects, here objects are the bars
plt.show()

# %% [markdown]
# ## ***Interpretation: According to data, 32% of employees stay away from the company and 14% of employee's distance from home is 1/2 km from the company.

# %% [markdown]
# ## 5.Analysis of Education field: Types of Education

# %%
info_of_cat("EducationField")
# Out:
# Unique values in EducationField are: ['Life Sciences' 'Other' 'Medical' 'Marketing' nan 'Technical Degree'
#  'Human Resources']
# Mode of EducationField is Life Sciences
# Number of missing values in EducationField is 12

# %% [markdown]
# ###### EducationField is a nominal datatype.

# %%
edu_mode = df.EducationField.mode()[0]
print(edu_mode)
df["EducationField"].fillna(edu_mode, inplace = True)
# Out:
# Life Sciences

# %% [markdown]
# ## Visual Presentation of Education Field Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "EducationField" column
data = df["EducationField"].value_counts()

# Get the unique categories (labels) in the "EducationField" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set2', n_colors=len(labels))

# Plot a countplot on the first subplot
a=sns.countplot(x='EducationField', data=df, order=labels, palette=colors, ax=ax[0])
a.set_xticklabels(a.get_xticklabels(), rotation = 40 , ha = "right")
a.set_title("Education Field Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode = [0.02, 0.02,0.03,0.07,0.1,0.3],pctdistance = 0.5 ,shadow=True, startangle=30)
plt.title("Education Field Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: Most of the employees are from the Life Science & Medical Education fields and only a few are from Human resources Eudcation field.

# %% [markdown]
# ## 6.Analysis of Gender Field : The gender of the employee(Male & Female)

# %%
info_of_cat("Gender")
# Out:
# Unique values in Gender are: ['Female' 'Male' nan]
# Mode of Gender is Male
# Number of missing values in Gender is 45

# %% [markdown]
# ###### Gender field is a nominal datatype.

# %%
gender_mode = df.Gender.mode()[0]
print(gender_mode)
df["Gender"].fillna(gender_mode, inplace = True)
# Out:
# Male

# %% [markdown]
# ## Visual presentation of Gender Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "Gender" column
data = df["Gender"].value_counts()

# Get the unique categories (labels) in the "Gender" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('hls', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='Gender', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Gender Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.02]*len(labels), shadow=True, startangle=90)
plt.title("Gender Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: The dataset indicates that 60% are Males employees in the company and only 39% of Females employees are there.

# %% [markdown]
# ## 7.Analysis of Environment Satisfaction field: Environment satisfaction on a scale of 1 to 5

# %%
info_of_cat("EnvironmentSatisfaction")
# Out:
# Unique values in EnvironmentSatisfaction are: [2 3 4 1]
# Mode of EnvironmentSatisfaction is 3
# Number of missing values in EnvironmentSatisfaction is 0

# %% [markdown]
# ###### Envirnoment satisfaction field is a nominal datatype.

# %% [markdown]
# ## Visual Presentation of Environment Satisfaction Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "EnvironmentSatisfaction" column
data = df["EnvironmentSatisfaction"].value_counts()

# Get the unique categories (labels) in the "EnvironmentSatisfaction" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('husl', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='EnvironmentSatisfaction', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Environment Satisfaction Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.02]*len(labels), shadow=True, startangle=90)
plt.title("Environment Satisfaction Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: 61% of employess are satisfied with the company environment.

# %% [markdown]
# ## 8.Analysis of job involvement field:  Employees job involvement on a scale of 1 to 5

# %%
info_of_cat("JobInvolvement")
# Out:
# Unique values in JobInvolvement are: [3 2 4 1]
# Mode of JobInvolvement is 3
# Number of missing values in JobInvolvement is 0

# %% [markdown]
# ###### Job involvemnet field is a nominal datatye.

# %% [markdown]
# ## Visual presentation of Job involvement Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "JobInvolvement" column
data = df["JobInvolvement"].value_counts()

# Get the unique categories (labels) in the "JobInvolvement" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('husl', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='JobInvolvement', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Job Involvement Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode = [0.02, 0.02,0.07,0.2], shadow=True, startangle=50)
plt.title("Job Involvement Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: The dataset indicates that 59% of the scale of employees Jobinvolvment in the company.

# %% [markdown]
# ## 9.Analysis of Job role field: The job role of the employee

# %%
info_of_cat("JobRole")
# Out:
# Unique values in JobRole are: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' nan 'Human Resources']
# Mode of JobRole is Sales Executive
# Number of missing values in JobRole is 10

# %% [markdown]
# ###### Job role is a nominal datatype.

# %%
jobrole_mode = df.JobRole.mode()[0]
print(jobrole_mode)
df["JobRole"].fillna(jobrole_mode, inplace = True)
# Out:
# Sales Executive

# %% [markdown]
# ## Visual presentation of Job role Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "JobRole" column
data = df["JobRole"].value_counts()

# Get the unique categories (labels) in the "JobRole" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('tab10', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='JobRole', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Job Role Count")
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation =90)

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.01]*len(labels), shadow=True, startangle=90)
plt.title("Job Role Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: Most of the employees job roles are in Sales Executive, Research Scientist and Laboratory Technician.

# %% [markdown]
# ## 10.Analysis of JobSatisfaction field: Job role satisfaction of the employee on a scale of 1 to 5

# %%
info_of_cat("JobSatisfaction")
# Out:
# Unique values in JobSatisfaction are: [4 2 3 1]
# Mode of JobSatisfaction is 4
# Number of missing values in JobSatisfaction is 0

# %% [markdown]
# ###### JobSatisfaction field is a nominal datatype.

# %% [markdown]
# ## Visual presentation of JobSatisfaction Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "JobSatisfaction" column
data = df["JobSatisfaction"].value_counts()

# Get the unique categories (labels) in the "JobSatisfaction" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('husl', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='JobSatisfaction', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Job Satisfaction Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%",explode=[0.02]*len(labels), shadow=True, startangle=60)
plt.title("Job Satisfaction Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: Most of the employees are satisfied with their Job role on a scale of 3 and 4.

# %% [markdown]
# ## 11.Anaylsis of Marital Status field: Marital status of an employee

# %%
info_of_cat("MaritalStatus")
# Out:
# Unique values in MaritalStatus are: ['Single' 'Married' nan 'Divorced']
# Mode of MaritalStatus is Married
# Number of missing values in MaritalStatus is 56

# %% [markdown]
# ###### Marital status field is a nomial datatype.

# %%
maritals_mode = df.MaritalStatus.mode()[0]
print(maritals_mode)
df["MaritalStatus"].fillna(maritals_mode, inplace = True)
# Out:
# Married

# %% [markdown]
# ## Visual presentation of Marital Status Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "MaritalStatus" column
data = df["MaritalStatus"].value_counts()

# Get the unique categories (labels) in the "MaritalStatus" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set3', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='MaritalStatus', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Marital Status Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.02]*len(labels), shadow=True, startangle=90)
plt.title("Marital Status Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: According to data, 48% of employees are Married , 30% of employees are Single and 21% of employees are Divorced.

# %% [markdown]
# ## 12.Analysis of NumCompaniesWorked field: The number of companies the employee worked for before joining

# %%
info_of_cat("NumCompaniesWorked")
# Out:
# Unique values in NumCompaniesWorked are: [8 1 6 9 0 4 5 2 7 3]
# Mode of NumCompaniesWorked is 1
# Number of missing values in NumCompaniesWorked is 0

# %% [markdown]
# ###### NumCompanies Worked field is a nominal datatype.

# %% [markdown]
# ## Visual presentation of NumCompaniesWorked Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "NumCompaniesWorked" column
data = df["NumCompaniesWorked"].value_counts()

# Get the unique categories (labels) in the "NumCompaniesWorked" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set3', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='NumCompaniesWorked', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Num Companies Worked Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.02]*len(labels),pctdistance = 0.5 ,shadow=True, startangle=30)
plt.title("Num Companies Worked Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: According to data, 34% of employees are worked in one company for before joining the company.

# %% [markdown]
# ## 13.Analysis of Over18 field: Whether the employee is above 18 years (Yes or No)

# %%
info_of_cat("Over18")
# Out:
# Unique values in Over18 are: ['Y' nan]
# Mode of Over18 is Y
# Number of missing values in Over18 is 54

# %% [markdown]
# ###### Over18 field is nominal datatye.

# %%
over18_mode = df.Over18.mode()[0]
print(over18_mode)
df["Over18"].fillna(over18_mode, inplace = True)
# Out:
# Y

# %% [markdown]
# ## ***Interpretation: The data indicates that the majority of the employee's ages are over 18 years.

# %% [markdown]
# ## 14.Analysis of OverTime field: Whether the employee is working overtime (Yes or No)

# %%
info_of_cat("OverTime")
# Out:
# Unique values in OverTime are: ['Yes' 'No']
# Mode of OverTime is No
# Number of missing values in OverTime is 0

# %% [markdown]
# ###### OverTime field is a nominal datatype.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Calculate the value counts of the "OverTime" column
data = df["OverTime"].value_counts()

# Get the unique categories (labels) in the "OverTime" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('hls', n_colors=len(labels))

# Plot a count plot on the first subplot
sns.countplot(x='OverTime', data=df, order=labels, palette=colors, ax=axes[0])
axes[0].set_title("OverTime Count")

# Plot a donut pie chart on the second subplot
wedges, texts, autotexts = axes[1].pie(data, labels=labels, colors=colors, autopct="%0.2f%%", startangle=30, wedgeprops=dict(width=0.4))
center_circle = plt.Circle((0, 0), 0.3, color='white')
axes[1].add_artist(center_circle)
axes[1].set_title("OverTime Distribution")

# Set aspect ratio to be equal to ensure a circular shape in the pie chart
axes[1].axis('equal')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.4)

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: Only 28% of employees are working Over time in the Company.

# %% [markdown]
# ## 15.Analysis of PerformanceRating field: Performance rating of an employee on the scale of 1 to 5

# %%
info_of_cat("PerformanceRating")
# Out:
# Unique values in PerformanceRating are: [3 4]
# Mode of PerformanceRating is 3
# Number of missing values in PerformanceRating is 0

# %% [markdown]
# ###### Performance rating field is a nominal datatype.

# %% [markdown]
# ## Visual presentation of PerformanceRating Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "PerformanceRating" column
data = df["PerformanceRating"].value_counts()

# Get the unique categories (labels) in the "PerformanceRating" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('husl', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='PerformanceRating', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Performance Rating Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%",explode=[0.02]*len(labels), shadow=True, startangle=60)
plt.title("Performance Rating Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: The majority of the performance rating scale is 3.

# %% [markdown]
# ## 16.Analysis of RelationshipSatisfaction field: Relation with the manager on a scale of 1 to 5

# %%
info_of_cat("RelationshipSatisfaction")
# Out:
# Unique values in RelationshipSatisfaction are: [1 4 2 3]
# Mode of RelationshipSatisfaction is 3
# Number of missing values in RelationshipSatisfaction is 0

# %% [markdown]
# ###### Relationship Satisfaction field is nominal datatype.

# %% [markdown]
# ## Visual presentation of RelationshipSatisfaction Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "RelationshipSatisfaction" column
data = df["RelationshipSatisfaction"].value_counts()

# Get the unique categories (labels) in the "RelationshipSatisfaction" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('husl', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='RelationshipSatisfaction', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Relationship Satisfaction Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%",explode=[0.02]*len(labels), shadow=True, startangle=60)
plt.title("Relationship Satisfaction Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: Most of the employees are satisfied with their relationship with the manager in the company on a scale of 3 and 4.

# %% [markdown]
# ## 17.Analysis of TrainingTimesLastYear field: Years passed of training

# %%
info_of_cat("TrainingTimesLastYear")
# Out:
# Unique values in TrainingTimesLastYear are: [0 3 2 5 1 4 6]
# Mode of TrainingTimesLastYear is 2
# Number of missing values in TrainingTimesLastYear is 0

# %% [markdown]
# ###### TraningTimeLastYear field is a nomianl datatype.

# %% [markdown]
# ## Visual presentation of TrainingTimesLastYear Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "TrainingTimesLastYear" column
data = df["TrainingTimesLastYear"].value_counts()

# Get the unique categories (labels) in the "TrainingTimesLastYear" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('Set3', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='TrainingTimesLastYear', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("Training Times Last Year Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%", explode=[0.02]*len(labels),pctdistance = 0.5 ,shadow=True, startangle=30)
plt.title("Training Times Last Year Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation: The dataset indicates that 70% of employees' training time last year is 2 and 3 years.

# %% [markdown]
# ## 18.Analysis of WorkLifeBalance field: Ratings of an employee in terms of work and life balance on a scale of 1 to 5

# %%
info_of_cat("WorkLifeBalance")
# Out:
# Unique values in WorkLifeBalance are: [1 3 2 4]
# Mode of WorkLifeBalance is 3
# Number of missing values in WorkLifeBalance is 0

# %% [markdown]
# ###### WorkLifeBalance field is a nominal datatype.

# %% [markdown]
# ## Visual presentation of WorkLifeBalance Attribute

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

# Calculate the value counts of the "WorkLifeBalance" column
data = df["WorkLifeBalance"].value_counts()

# Get the unique categories (labels) in the "WorkLifeBalance" column
labels = data.index.tolist()

# Generate a color palette
colors = sns.color_palette('husl', n_colors=len(labels))

# Plot a countplot on the first subplot
sns.countplot(x='WorkLifeBalance', data=df, order=labels, palette=colors, ax=ax[0])
ax[0].set_title("WorkLifeBalance  Count")

# Plot a pie chart on the second subplot using the color palette
ax[1].pie(x=data, labels=labels, colors=colors, autopct="%0.2f%%",explode=[0.02]*len(labels), shadow=True, startangle=60)
plt.title("WorkLifeBalance  Distribution")

# Display the figure
plt.show()

# %% [markdown]
# ## ***Interpretation:  60% of the Ratings of employees in terms of work and life balance on the scale is 3.

# %% [markdown]
# ## 19.Analysis of YearsInCurrentRole field: The number of years since the employee is working in the same role

# %%
info_of_cat("YearsInCurrentRole")
# Out:
# Unique values in YearsInCurrentRole are: [ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
# Mode of YearsInCurrentRole is 2
# Number of missing values in YearsInCurrentRole is 0

# %% [markdown]
# ###### YearsInCurrentRole field an ordinal datatype (Categorical) as it is having hierarchy in it.

# %% [markdown]
# ## ***Interpretation: The number of years some employees are working in the same role is many years.This could be a result of human error in data.
#
# Note: This might not always be the correct approach unless verified by a domain expert!

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["YearsInCurrentRole"])
ax.set_title("Years In Current Role Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
    fig.set_figheight(10)                                                             # annotate: used to annotate over objects, here objects are the bars
    fig.set_figwidth(30)
plt.show()

# %% [markdown]
# ## ***Interpretation: Very few employees are working in the same role for more than 2 years. However, there are some cases where the years in the company are more than 18 years, which is abnormal. Hence, data clearing might be required.

# %% [markdown]
# ## Outliers Analysis and Treatment:

# %%
#IQR method for outfilers treatment
Q1 = df['YearsInCurrentRole'].quantile(0.25)
Q3 = df['YearsInCurrentRole'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 5.0

# %% [markdown]
# The employees who have worked in the same role is more than 5 years are being replaced with the mean of the YearsInCurrentRole.

# %%
mean = int(df.YearsInCurrentRole.mean())
# accessing the data higher than 5
x = df[df["YearsInCurrentRole"] > 5].index
for index in x:
    df.loc[index, "YearsInCurrentRole"] = mean

# %%
info_of_cat("YearsInCurrentRole")
# Out:
# Unique values in YearsInCurrentRole are: [4 0 2 5 3 1]
# Mode of YearsInCurrentRole is 4
# Number of missing values in YearsInCurrentRole is 0

# %% [markdown]
# ## Visual Presentation of Years In Current Role Attribute

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["YearsInCurrentRole"])
ax.set_title("Years In Current Role Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
                                                                    # annotate: used to annotate over objects, here objects are the bars
plt.show()

# %% [markdown]
# ## ***Interpretation: 42% of employees are working in the same role for 4 years in the company.

# %% [markdown]
# ## 20.Analysis of YearsSinceLastPromotion field: The number of years since the employee got their promotion

# %%
info_of_cat("YearsSinceLastPromotion")
# Out:
# Unique values in YearsSinceLastPromotion are: [ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
# Mode of YearsSinceLastPromotion is 0
# Number of missing values in YearsSinceLastPromotion is 0

# %% [markdown]
# ###### YearsSinceLastPromotion field an ordinal datatype (Categorical) as it is having hierarchy in it.

# %% [markdown]
# ## ***Interpretation: The number of years some employees get their last promotion after many years.This could be a result of human error in data.
#
# Note: This might not always be the correct approach unless verified by a domain expert!

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["YearsSinceLastPromotion"])
ax.set_title("Years Since Last Promotion Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
    fig.set_figheight(10)                                                             # annotate: used to annotate over objects, here objects are the bars
    fig.set_figwidth(30)
plt.show()                             # annotate: used to annotate over objects, here objects are the bars

# %% [markdown]
# ## ***Interpretation: Very few employees get last promoted after 2 years. However, there are some cases where the years of last promotion in the company are more than 15 years, which is abnormal. Hence, data clearing might be required.

# %% [markdown]
# ## Outliers Analysis and Treatment:

# %%
#IQR method for outfilers treatment
Q1 = df['YearsSinceLastPromotion'].quantile(0.25)
Q3 = df['YearsSinceLastPromotion'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 3.0

# %% [markdown]
# The employees who have got last promoted for more than 3 years are being replaced with the mean of the YearsSinceLastPromtion.

# %%
mean = int(df.YearsInCurrentRole.mean())
# accessing the data higher than 3
x = df[df["YearsSinceLastPromotion"] > 3].index
for index in x:
    df.loc[index, "YearsSinceLastPromotion"] = mean

# %%
info_of_cat("YearsSinceLastPromotion")
# Out:
# Unique values in YearsSinceLastPromotion are: [0 1 3 2]
# Mode of YearsSinceLastPromotion is 0
# Number of missing values in YearsSinceLastPromotion is 0

# %% [markdown]
# ## Visual presentation of YearsSinceLastPromotion Attribute

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["YearsSinceLastPromotion"])
ax.set_title("Years Since Last Promotion Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
                                                                    # annotate: used to annotate over objects, here objects are the bars
plt.show()

# %% [markdown]
# ## ***Interpretation: 39% of employees are getting promoted recently, 32% of employees are getting last promoted in 2 years and very few are getting last promoted in 3 years.

# %% [markdown]
# ## 21.Analysis of YearsWithCurrManager field: The number of years spent with the current manager

# %%
info_of_cat("YearsWithCurrManager")
# Out:
# Unique values in YearsWithCurrManager are: [ 5  7  0  2  6  8  3 11 17  1  4 12  9 10 15 13 16 14]
# Mode of YearsWithCurrManager is 2
# Number of missing values in YearsWithCurrManager is 0

# %% [markdown]
# ###### YearWithCurrManager field an ordinal datatype (Categorical) as it is having hierarchy in it.

# %% [markdown]
# ## ***Interpretation: The number of years some employees are with their current manager is many years. This could be a result of human error in data.
# Note: This might not always be the correct approach unless verified by a domain expert!

# %% [markdown]
# ## Visual presentation of YearsWithCurrManager Attribute

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["YearsWithCurrManager"])
ax.set_title("Years With Current Manager Count")

for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
    fig.set_figheight(10)                                                             # annotate: used to annotate over objects, here objects are the bars
    fig.set_figwidth(30)
plt.show()

# %% [markdown]
#  ## ***Interpretation: Very few employees are working with their current manager for 2 years. However, there are some cases where the working with their current manager in the company is more than 17 years, which is abnormal. Hence, data clearing might be required.

# %% [markdown]
# ## Outliers Analysis and Treatment:

# %%
#IQR method for outfilers treatment
Q1 = df['YearsWithCurrManager'].quantile(0.25)
Q3 = df['YearsWithCurrManager'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 5.0

# %% [markdown]
# The employees who have worked with their current manager for more than 5 years are being replaced with the mean of the YearsWithCurrManager.

# %%
mean = int(df.YearsInCurrentRole.mean())
# accessing the data higher than 5
x = df[df["YearsWithCurrManager"] > 5].index
for index in x:
    df.loc[index, "YearsWithCurrManager"] = mean

# %%
info_of_cat("YearsWithCurrManager")
# Out:
# Unique values in YearsWithCurrManager are: [5 2 0 3 1 4]
# Mode of YearsWithCurrManager is 2
# Number of missing values in YearsWithCurrManager is 0

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["YearsWithCurrManager"])
ax.set_title("Years With Current Manager Count")


for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height()*100 /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
                                                                    # annotate: used to annotate over objects, here objects are the bars
plt.show()

# %% [markdown]
# ## ***Interpretation: 58% of employees are working with their current manager for 2 years.

# %% [markdown]
# # $$\;\;\;\;\;\;Univariate \ Analysis \ of \ Numerical \ Variables$$

# %% [markdown]
# ## User defined function for calculating mean, median, mode,  standard deviation, and count of all null values

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %% [markdown]
# ## 22.Analysis of Age: Age of the Employee

# %%
info_of_numerical("Age")
# Out:
# The mean of the Age is 36.93015214384509
# The median of the Age is 36.0
# The mode of the Age is 34.0
# The standard deviation of the Age is 9.16220404447615
# Number of missing values in the Age is 24

# %% [markdown]
# ###### Age of the Employee is continuous data (Numerical).

# %%
Age_m = df.Age.mode()[0]
print(Age_m)
df["Age"].fillna(Age_m, inplace = True)
# Out:
# 34.0

# %% [markdown]
# ## Visual presentation of Age Attribute

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["Age"], ax=ax[1], color="y")
ax[1].set_title("Age Distribution")  

# Plotting the boxplot
sns.boxplot(x=df["Age"], ax=ax[0])
ax[0].set_title("Age Boxplot")  

plt.show()

# %% [markdown]
# ## ***Interpretation: Most likely employees' ages follow the normal distribution. Most of the employees are between 30 to 45 years of age.

# %% [markdown]
# ## 23. Analysis of Hourly Rate:Hourly salary earned by the employee

# %%
info_of_numerical("HourlyRate")
# Out:
# The mean of the HourlyRate is 65.89115646258503
# The median of the HourlyRate is 66.0
# The mode of the HourlyRate is 66
# The standard deviation of the HourlyRate is 20.329427593996158
# Number of missing values in the HourlyRate is 0

# %% [markdown]
# ###### Hourly rate of employee is continuous data(numerical).

# %% [markdown]
# ## Visual presentation of HourlyRate Attribute

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["HourlyRate"], ax=ax[1], color="y")
ax[1].set_title("Hourly Rate Distribution")  
# Plotting the boxplot
sns.boxplot(x=df["HourlyRate"], ax=ax[0])
ax[0].set_title("Hourly Rate Boxplot") 

plt.show()

# %% [markdown]
# ## ***Interpretation: The dataset indicates that the Hourly Rate salary earned by the employees is 50 to 85.

# %% [markdown]
# ## 24.Analysis of Monthly Income: Monthly salary of an employee

# %%
info_of_numerical("MonthlyIncome")
# Out:
# The mean of the MonthlyIncome is 6502.931292517007
# The median of the MonthlyIncome is 4919.0
# The mode of the MonthlyIncome is 2342
# The standard deviation of the MonthlyIncome is 4707.956783097995
# Number of missing values in the MonthlyIncome is 0

# %% [markdown]
# ###### Monthly Income of Employee is continuous data(numerical).

# %% [markdown]
# ## Visual presentation of MonthlyIncome Attribute

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["MonthlyIncome"], ax=ax[1], color="y")
ax[1].set_title("Monthly Income Distribution")  
# Plotting the boxplot
sns.boxplot(x=df["MonthlyIncome"], ax=ax[0])
ax[0].set_title("Monthly Income Boxplot") 

plt.show()

# %% [markdown]
# ## Outliers Analysis and Treatment:

# %%
# Calculate the interquartile range (IQR)
Q1 = df['MonthlyIncome'].quantile(0.25)
Q3 = df['MonthlyIncome'].quantile(0.75)
IQR = Q3 - Q1

# Define the outlier threshold
outlier_threshold = 1.5

# Identify outliers using the IQR method
lower_bound = Q1 - outlier_threshold * IQR
upper_bound = Q3 + outlier_threshold * IQR
outliers = df[(df['MonthlyIncome'] < lower_bound) | (df['MonthlyIncome'] > upper_bound)]

# Calculate the mean of non-outlier data
median = df[(df['MonthlyIncome'] >= lower_bound) & (df['MonthlyIncome'] <= upper_bound)]['MonthlyIncome'].median()

# Replace outliers with the mean value
df.loc[df['MonthlyIncome'] < lower_bound, 'MonthlyIncome'] = median
df.loc[df['MonthlyIncome'] > upper_bound, 'MonthlyIncome'] = median

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["MonthlyIncome"], ax=ax[1], color="y")
ax[1].set_title("Monthly Income Distribution")  
# Plotting the boxplot
sns.boxplot(x=df["MonthlyIncome"], ax=ax[0])
ax[0].set_title("Monthly Income Boxplot") 

plt.show()

# %% [markdown]
# ## *** Interpretation: Most of the employee's Monthy Income is between 2500 to 6500.

# %% [markdown]
# ## 25. Analysis of total working years :Total number of working years of an employee

# %%
info_of_numerical("TotalWorkingYears")
# Out:
# The mean of the TotalWorkingYears is 11.279591836734694
# The median of the TotalWorkingYears is 10.0
# The mode of the TotalWorkingYears is 10
# The standard deviation of the TotalWorkingYears is 7.780781675515004
# Number of missing values in the TotalWorkingYears is 0

# %% [markdown]
# ###### Total working years of the employee is the continuous data(numerical).

# %% [markdown]
# ## Visual presentation of TotalWorkingYears Attribute

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["TotalWorkingYears"], ax=ax[1], color="y")
ax[1].set_title("Total Working Years Distribution")  
# Plotting the boxplot
sns.boxplot(x=df["TotalWorkingYears"], ax=ax[0])
ax[0].set_title("Total Working Years Boxplot") 

plt.show()

# %% [markdown]
# ## Outliers Analysis and Treatment:

# %%
# Calculate the interquartile range (IQR)
Q1 = df['TotalWorkingYears'].quantile(0.25)
Q3 = df['TotalWorkingYears'].quantile(0.75)
IQR = Q3 - Q1

# Define the outlier threshold
outlier_threshold = 1.5

# Identify outliers using the IQR method
lower_bound = Q1 - outlier_threshold * IQR
upper_bound = Q3 + outlier_threshold * IQR
outliers = df[(df['TotalWorkingYears'] < lower_bound) | (df['TotalWorkingYears'] > upper_bound)]

# Calculate the mean of non-outlier data
median = df[(df['TotalWorkingYears'] >= lower_bound) & (df['TotalWorkingYears'] <= upper_bound)]['TotalWorkingYears'].median()

# Replace outliers with the mean value
df.loc[df['TotalWorkingYears'] < lower_bound, 'TotalWorkingYears'] = median
df.loc[df['TotalWorkingYears'] > upper_bound, 'TotalWorkingYears'] = median

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["TotalWorkingYears"], ax=ax[1], color="y")
ax[1].set_title("Total Working Years Distribution")  
# Plotting the boxplot
sns.boxplot(x=df["TotalWorkingYears"], ax=ax[0])
ax[0].set_title("Total Working Years Boxplot") 

plt.show()

# %% [markdown]
# ## ***Interpretation:  Most of the employees are working for the last 5 to 14 years with a company.

# %% [markdown]
# ## 26. Analysis of Year At Company: Total number of years the employee is working at IBM

# %%
info_of_numerical("YearsAtCompany")
# Out:
# The mean of the YearsAtCompany is 7.0081632653061225
# The median of the YearsAtCompany is 5.0
# The mode of the YearsAtCompany is 5
# The standard deviation of the YearsAtCompany is 6.126525152403566
# Number of missing values in the YearsAtCompany is 0

# %% [markdown]
# ###### Years at company of the the employee is the continuous data(numerical)

# %% [markdown]
# ## Visual presentation of YearsAtCompany Attribute

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["YearsAtCompany"], ax=ax[1], color="y")
ax[1].set_title("Years At Company Distribution")  
# Plotting the boxplot
sns.boxplot(x=df["YearsAtCompany"], ax=ax[0])
ax[0].set_title("Years At Company Boxplot") 

plt.show()

# %% [markdown]
# ## Outliers Analysis and Treatment:

# %%
# Calculate the interquartile range (IQR)
Q1 = df['YearsAtCompany'].quantile(0.25)
Q3 = df['YearsAtCompany'].quantile(0.75)
IQR = Q3 - Q1

# Define the outlier threshold
outlier_threshold = 1.5

# Identify outliers using the IQR method
lower_bound = Q1 - outlier_threshold * IQR
upper_bound = Q3 + outlier_threshold * IQR
outliers = df[(df['YearsAtCompany'] < lower_bound) | (df['YearsAtCompany'] > upper_bound)]

# Calculate the mean of non-outlier data
median = df[(df['YearsAtCompany'] >= lower_bound) & (df['YearsAtCompany'] <= upper_bound)]['YearsAtCompany'].median()

# Replace outliers with the mean value
df.loc[df['YearsAtCompany'] < lower_bound, 'YearsAtCompany'] = median
df.loc[df['YearsAtCompany'] > upper_bound, 'YearsAtCompany'] = median

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the histogram
sns.histplot(x=df["YearsAtCompany"], ax=ax[1], color="y")
ax[1].set_title("Years At Company Distribution")  
# Plotting the boxplot
sns.boxplot(x=df["YearsAtCompany"], ax=ax[0])
ax[0].set_title("Years At Company Boxplot") 

plt.show()

# %% [markdown]
# ## ***Interpretation : The majority of the employees are working for less than 8 years.

# %% [markdown]
# # Level 2 Analysis

# %% [markdown]
# ## CAT-CAT ANALYSIS (Relationship between categorical and categorical data)

# %% [markdown]
# ## 1.Relationship of Attrition with BusinessTravel

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Attrition", hue = "BusinessTravel", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation : The majority of the employees who Business travel rarely they are attrited.

# %% [markdown]
# ## 2.Relationship of Attrition with Department

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Department", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: In the Research & Development department of employees attrition rate is high.

# %% [markdown]
# ## 3.Relationship with Attrition  with Distance from Home

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "DistanceFromHome", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: The majority of the employees who stay away from the company are Attrited.

# %% [markdown]
# ## 4.Relationship of Attrition with Eduaction field

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "EducationField", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: Life Science and Medical field have higher Attrition rates compared to other educationfields.

# %% [markdown]
# ## 5.Relationship of Attrition with EnvironmentSatisfaction

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Attrition", hue = "EnvironmentSatisfaction", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: The Environment Satisfaction scale on 1 have higher attrition rate.

# %% [markdown]
# ## 6.Relationship of Attrition with Gender

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interprertation: Percentage of Male employees are getting left than Female.

# %% [markdown]
# ## 7.Relationship of Attrition with JobInvolvement

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "JobInvolvement", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: The Job Involvement scale on 3 have higher attrition rate .

# %% [markdown]
# ## 8.Relationship of Attrition with JobRole

# %%
fig, ax = plt.subplots( figsize= (10, 7))
ax = sns.countplot(x = "JobRole", hue = "Attrition", data = df)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90 , ha = "right") 
plt.show()

# %% [markdown]
# ## ***Interpretation: Sales Executive, Research Scientist and Laboratory technician have higher Attrition rates compared to others JobRole.

# %% [markdown]
# ## 9.Relationship of Attrition with JobSatisfaction

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Attrition", hue = "JobSatisfaction", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: The job satisfaction scale on 1 and 3 have higher attrition rates compared to other scale.

# %% [markdown]
# ## 10.Relationship of Attrition with MaritalStatus

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "MaritalStatus", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation:  An Employee of single marital status have higher attrition rate.

# %% [markdown]
# ## 11.Relationship of Attrition with NumCompaniesWorked

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "NumCompaniesWorked", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation:

# %% [markdown]
# ## 12.Relationship of Attrition with Over18

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Over18", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation:

# %% [markdown]
# ## 13.Relationship of Attrition with OverTime

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "OverTime", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: Those employees are working overtime in the company their attrition rate is high.

# %% [markdown]
# ## 14.Relationship of Attrition with PerformanceRating

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "PerformanceRating", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: Most of the attrited employee's Performance rating scale of 3.

# %% [markdown]
# ## 15.Relationship of Attrition with RelationshipSatisfaction

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Attrition", hue = "RelationshipSatisfaction", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation:Employees who are attrited or existing have a relationship with their manager maximum scale on a of 3 and 4.

# %% [markdown]
# ## 16.Relationship of Attrition with TrainingTimesLastYear

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TrainingTimesLastYear", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: Most of the attrited employees who have passed training their training times are last 2 and 3 years.

# %% [markdown]
# ## 17.Relationship of Attrition with WorkLifeBalance

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "WorkLifeBalance", hue = "Attrition", data = df)
plt.show()

# %% [markdown]
# ## ***Interpretation: The majority of attrited employee's ratings in terms of work and life balance on a scale is 3.

# %% [markdown]
# ## CAT-NUM ANALYSIS (Relationship between categorical and numerical data)

# %% [markdown]
# ## 18.Relationship of Attrition with Age

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["Age"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["Age"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ## ***Interpretation:

# %% [markdown]
# ## 19.Relationship  of Attrition with Hourly Rate

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["HourlyRate"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["HourlyRate"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ## ***Interpretation:

# %% [markdown]
# ## 20.Relationship of Attrition with Monthly Income

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["MonthlyIncome"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["MonthlyIncome"], x = df["Attrition"], ax = ax[1])
plt.show()

# %%
# Calculate quartiles and IQR for each category of Attrition
q1 = df.groupby("Attrition")["MonthlyIncome"].quantile(0.25)
q3 = df.groupby("Attrition")["MonthlyIncome"].quantile(0.75)
iqr = q3 - q1

# Calculate the upper and lower fences for outlier detection
lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr

# Identify outliers for each category
outliers = (
    (df["Attrition"] == "Yes") & (df["MonthlyIncome"] > upper_fence["Yes"]) |
    (df["Attrition"] == "Yes") & (df["MonthlyIncome"] < lower_fence["Yes"]) |
    (df["Attrition"] == "No") & (df["MonthlyIncome"] > upper_fence["No"]) |
    (df["Attrition"] == "No") & (df["MonthlyIncome"] < lower_fence["No"])
)

# Apply outlier treatment (e.g., replace outliers with NaN)
df.loc[outliers, "MonthlyIncome"] = np.nan

# Create updated plots to visualize the treated outliers
fig, ax = plt.subplots(1, 2, figsize=(15, 7))
sns.histplot(x=df["MonthlyIncome"], hue=df["Attrition"], ax=ax[0])
sns.boxplot(y=df["MonthlyIncome"], x=df["Attrition"], ax=ax[1])
plt.show()

# %% [markdown]
# ## ***Interpretation:

# %% [markdown]
# ## 21.Relatioship of Attrition with Total workings years

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["TotalWorkingYears"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["TotalWorkingYears"], x = df["Attrition"], ax = ax[1])
plt.show()

# %%
# Calculate quartiles and IQR for each category of Attrition
q1 = df.groupby("Attrition")["TotalWorkingYears"].quantile(0.25)
q3 = df.groupby("Attrition")["TotalWorkingYears"].quantile(0.75)
iqr = q3 - q1

# Calculate the upper and lower fences for outlier detection
lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr

# Identify outliers for each category
outliers = (
    (df["Attrition"] == "Yes") & (df["TotalWorkingYears"] > upper_fence["Yes"]) |
    (df["Attrition"] == "Yes") & (df["TotalWorkingYears"] < lower_fence["Yes"]) |
    (df["Attrition"] == "No") & (df["TotalWorkingYears"] > upper_fence["No"]) |
    (df["Attrition"] == "No") & (df["TotalWorkingYears"] < lower_fence["No"])
)

# Apply outlier treatment (e.g., replace outliers with NaN)
df.loc[outliers, "TotalWorkingYears"] = np.nan

# Create updated plots to visualize the treated outliers
fig, ax = plt.subplots(1, 2, figsize=(15, 7))
sns.histplot(x=df["TotalWorkingYears"], hue=df["Attrition"], ax=ax[0])
sns.boxplot(y=df["TotalWorkingYears"], x=df["Attrition"], ax=ax[1])
plt.show()

# %% [markdown]
# ## ***Interpretation:

# %% [markdown]
# ## 22.Relationship of Attrition of Years at company

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["YearsAtCompany"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["YearsAtCompany"], x = df["Attrition"], ax = ax[1])
plt.show()

# %%
# Calculate quartiles and IQR for each category of Attrition
q1 = df.groupby("Attrition")["YearsAtCompany"].quantile(0.25)
q3 = df.groupby("Attrition")["YearsAtCompany"].quantile(0.75)
iqr = q3 - q1

# Calculate the upper and lower fences for outlier detection
lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr

# Identify outliers for each category
outliers = (
    (df["Attrition"] == "Yes") & (df["YearsAtCompany"] > upper_fence["Yes"]) |
    (df["Attrition"] == "Yes") & (df["YearsAtCompany"] < lower_fence["Yes"]) |
    (df["Attrition"] == "No") & (df["YearsAtCompany"] > upper_fence["No"]) |
    (df["Attrition"] == "No") & (df["YearsAtCompany"] < lower_fence["No"])
)

# Apply outlier treatment (e.g., replace outliers with NaN)
df.loc[outliers, "YearsAtCompany"] = np.nan

# Create updated plots to visualize the treated outliers
fig, ax = plt.subplots(1, 2, figsize=(15, 7))
sns.histplot(x=df["YearsAtCompany"], hue=df["Attrition"], ax=ax[0])
sns.boxplot(y=df["YearsAtCompany"], x=df["Attrition"], ax=ax[1])
plt.show()

# %% [markdown]
# ## ***Interpretation:

# %% [markdown]
# # Level 3 Analysis

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### 1. Which age group of men has a larger Attrition.

# %%
# Create age labels
males = df[(df["Gender"]=="Male") & (df["Attrition"]=="Yes")] # accessing the data using conditional statements where & is a bitwise operator 
bins =     [0,30,40,50,60]                                             # Create the bins
labels =  ["Young", "Adult", "Senior", "Super-Seinor"]                   # setting the labels for the bins 
data = pd.cut(males["Age"], bins = bins, labels = labels)

data = data.value_counts()                                                      # value count is counting the number of values in the column
data
# Out:
# Young           61
# Adult           57
# Senior          21
# Super-Seinor    13
# Name: Age, dtype: int64

# %%
pie, ax = plt.subplots(figsize = [10,6])
plt.pie(x = data,autopct = "%.1f%%",explode = [0.02,0.03,0.06,0.2] ,labels =data.index, pctdistance = 0.5,shadow=True, startangle=30) #autopct is used to present the percentage, explode is used to seprate the pie
                                                                                            # pctdistance is the distance betweeen the percentage numbers on the pie
plt.title("Male Age group Attrition")
plt.show()

# %% [markdown]
# ### ***Interpretation: Adult and young group of men have higher attirition.

# %% [markdown]
#  ### 2.Analyze the attrited of male employees based on their departments.

# %%
data = df[(df["Gender"]=="Male") & (df["Attrition"]=="Yes")]

data = data["Department"] 
data = data.value_counts()
data
# Out:
# Research & Development    92
# Sales                     54
# Human Resources            6
# Name: Department, dtype: int64

# %%
pie, ax = plt.subplots(figsize = [10,6])
plt.pie(x = data,autopct = "%0.2f%%",explode = [0.02,0.02,0.2],labels =data.index, pctdistance = 0.5,shadow=True, startangle=30) #autopct is used to present the percentage, explode is used to seprate the pie
                                                                                            # pctdistance is the distance betweeen the percentage numbers on the pie
plt.title("Male Age group Attrition")
plt.show()

# %% [markdown]
# ### ***Interpretation: Research & Development department males are attrited more compared to those who are in Human Resources.

# %% [markdown]
# ### 3. Do you think the Hourlysalary earned by the male employee who attrited is different from those who are still within the company?

# %%
with_comp = df[(df["Gender"] == "Male") & (df["Attrition"] == "No")]
left_comp = df[(df["Gender"] == "Male") & (df["Attrition"] == "Yes")]
with_comp_mean = with_comp["HourlyRate"].mean()
left_comp_mean = left_comp["HourlyRate"].mean()
print(f"Men who are with the company their Hourly earned salary is {round(with_comp_mean, 3)}")
print(f"Men who left the company their Hourly earned salary is {round(left_comp_mean,3)}")
# Out:
# Men who are with the company their Hourly earned salary is 65.84
# Men who left the company their Hourly earned salary is 65.895

# %%
data = [66,65]
fig, ax = plt.subplots(figsize = [10,6])
plt.pie(data, labels = ["No", "Yes"],autopct = "%0.2f%%",shadow=True, startangle=60)
plt.title("Difference of Hourly Rate in Male")
plt.show()

# %% [markdown]
# ### 4. How does the over time and promotion effect the attrition?

# %%
correlate1 = df['YearsAtCompany'].corr(df["YearsSinceLastPromotion"])
plt.scatter(df["YearsAtCompany"],df["YearsSinceLastPromotion"])
plt.title("YearsAtCompany vs YearsSinceLastPromotion ")
plt.xlabel("Years At Company")
plt.ylabel("Years Since Last Promotion");
plt.show()

# %%
sns.countplot(x ="OverTime", hue = "Attrition", data = df)
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# ### ***Interpretation: The Promotion graph opens up an interesting perspective, as a lot of it getting spaced out towards the right hand side, indicating a positive correlation between these two variables may mean that people are not really growing within the company. Here we note two things. Firstly, there is a relatively higher percentage of people working overtime in the group of those who left, secondly, while things seem to be going in the right direction for the group of people who continue with firm, the opposite is happening in the other group. It seems that there may be a pattern of people leaving because they are not promoted although they work hard.

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=.8, square=True);
